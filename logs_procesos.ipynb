# %%
# %sql

CREATE TABLE IF NOT EXISTS challenge.control.process_log (
    ID_EJECUCION              STRING,
    JOB_ID                    STRING,
    RUN_ID                    STRING,
    NOMBRE_PROCESO            STRING,
    FECHA_EJECUCION            TIMESTAMP,
    FECHA_INICIO              TIMESTAMP,
    FECHA_FIN                 TIMESTAMP,
    ESTADO                    STRING,
    FILAS_ORIGEN_CSV             BIGINT,

    FILAS_BRONZE              BIGINT,
    FILAS_AFECTADAS_BRONZE    BIGINT,

    FILAS_AFECTADAS_SILVER    BIGINT,
    FILAS_ACTUALIZADAS_SILVER BIGINT,
    FILAS_INSERTADAS_SILVER   BIGINT,

    INSTANCIA_BASE_DATOS      STRING,
    NOMBRE_BASE_DATOS         STRING,

    TABLA_BRONZE              STRING,
    TABLA_SILVER              STRING
    
)
USING DELTA;

# %%
# %sql
DROP TABLE challenge.control.process_log
